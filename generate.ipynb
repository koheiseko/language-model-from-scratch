# %%
import torch
from tokenizers import Tokenizer

from languagemodel.model import Transformer

tokenizer = Tokenizer.from_pretrained("NousResearch/Llama-2-7b-hf")

ckpt = torch.load("outputs/ckpt_04072026_14.pt", map_location="cuda")
model_args = ckpt["model_args"]
model = Transformer(**model_args)
model.load_state_dict(ckpt["model"])
# Out:
# <All keys matched successfully>

# %%
prompt = "reading books is"

# %%
from languagemodel.generation import generate

prompt_tokens = tokenizer.encode(prompt).ids

response = generate(
    model=model,
    max_new_tokens=100,
    eos_id=0,
    prompt_tokens=prompt_tokens,
    device="cuda",
    temperature=0.8,
).tolist()

print(tokenizer.decode(response))
# Out:
# reading books is a snake. She learns that some numbers can make a loud noise and a loud noise. She likes the sound of sings, the trucks, the cars, the cars, the cars and the cars. She hugs the cars and the cars, the cars, the animals, and the animals.
#
# One day, her mom asked her to clean the living room. Lily wanted to look at the crib and the cars and the houses. But her mom said
